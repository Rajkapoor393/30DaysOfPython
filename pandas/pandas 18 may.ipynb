# %%
import pandas as pd

# %%
a = pd.read_csv('new.csv')

# %%
a
# Out:
#     1  2  3  4   hello
# 0   6  8  9  3   world
# 1  41  2  7  8    new
# 2   4  9  7  5      to
# 3   2  0  5  1  pandas

# %%
a.head()
# Out:
#     1  2  3  4   hello
# 0   6  8  9  3   world
# 1  41  2  7  8    new
# 2   4  9  7  5      to
# 3   2  0  5  1  pandas

# %%
a.tail(2)
# Out:
#    1  2  3  4   hello
# 2  4  9  7  5      to
# 3  2  0  5  1  pandas

# %%
a.dtypes
# Out:
# 1         int64
# 2         int64
# 3         int64
# 4         int64
# hello    object
# dtype: object

# %%
a
# Out:
#     1  2  3  4   hello
# 0   6  8  9  3   world
# 1  41  2  7  8    new
# 2   4  9  7  5      to
# 3   2  0  5  1  pandas

# %%
a['hello']
# Out:
# 0     world
# 1      new
# 2        to
# 3    pandas
# Name: hello, dtype: object

# %%
list(a['1'])
# Out:
# [6, 41, 4, 2]

# %%
a[['1','2']]
# Out:
#     1  2
# 0   6  8
# 1  41  2
# 2   4  9
# 3   2  0

# %%
a = pd.read_csv('new.csv', header = None, names=['x','y','z','a','b'])

# %%
a
# Out:
#     x  y  z  a       b
# 0   1  2  3  4   hello
# 1   6  8  9  3   world
# 2  41  2  7  8    new
# 3   4  9  7  5      to
# 4   2  0  5  1  pandas

# %%
pd.read_csv('new.csv', index_col = ['1'])
# Out:
#     2  3  4   hello
# 1
# 6   8  9  3   world
# 41  2  7  8    new
# 4   9  7  5      to
# 2   0  5  1  pandas

# %%
pd.read_csv('new.csv', skiprows =[1])
# Out:
#     1  2  3  4   hello
# 0  41  2  7  8    new
# 1   4  9  7  5      to
# 2   2  0  5  1  pandas

# %%
d1=pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')

# %%
type(d1)
# Out:
# list

# %%
len(d1)
# Out:
# 1

# %%
d1[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
d1[0].columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
pd.read_csv('new.csv', nrows=2)
# Out:
#     1  2  3  4  hello
# 0   6  8  9  3  world
# 1  41  2  7  8   new

# %%
pd.read_csv('new.csv').head(2)
# Out:
#     1  2  3  4  hello
# 0   6  8  9  3  world
# 1  41  2  7  8   new

# %%
df2=pd.read_csv('https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/ff414a1bcfcba32481e4d4e8db578e55872a2ca1/titanic.csv', sep = '\t')

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df2[['Embarked','Fare','Survived']]
# Out:
#     Embarked     Fare  Survived
# 0          S   7.2500         0
# 1          C  71.2833         1
# 2          S   7.9250         1
# 3          S  53.1000         1
# 4          S   8.0500         0
# ..       ...      ...       ...
# 151        S  66.6000         1
# 152        S   8.0500         0
# 153        S  14.5000         0
# 154        S   7.3125         0
# 155        C  61.3792         0
#
# [156 rows x 3 columns]

# %%
df2.to_csv('testing.csv')

# %%
df2.to_csv('testint.tsv',sep = '\t', index = False,header= False)

# %%
b = pd.read_csv('new.csv')

# %%
b
# Out:
#     1  2  3  4   hello
# 0   6  8  9  3   world
# 1  41  2  7  8    new
# 2   4  9  7  5      to
# 3   2  0  5  1  pandas

# %%
b.to_pickle("testpickle")

# %%
pd.read_pickle('testpickle')
# Out:
#     1  2  3  4   hello
# 0   6  8  9  3   world
# 1  41  2  7  8    new
# 2   4  9  7  5      to
# 3   2  0  5  1  pandas
