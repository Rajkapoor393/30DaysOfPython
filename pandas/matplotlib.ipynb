# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# !pip install plotly
# Out:
# Collecting plotly
#   Downloading https://files.pythonhosted.org/packages/70/56/eabdc7b7187cdb9d6121f6de2831ad5b85f7d002fa4bfe0476dbdb554bf6/plotly-4.8.1-py2.py3-none-any.whl (11.5MB)
# Collecting retrying>=1.3.3 (from plotly)
#   Downloading https://files.pythonhosted.org/packages/44/ef/beae4b4ef80902f22e3af073397f079c96969c69b2c7d52a57ea9ae61c9d/retrying-1.3.3.tar.gz
# Requirement already satisfied: six in c:\users\raj\anaconda3\lib\site-packages (from plotly) (1.12.0)
# Building wheels for collected packages: retrying
#   Building wheel for retrying (setup.py): started
#   Building wheel for retrying (setup.py): finished with status 'done'
#   Created wheel for retrying: filename=retrying-1.3.3-cp37-none-any.whl size=11435 sha256=2fd0215cd69e59c3b1de0cdf01b681252180b1711036ea397a6cff63e5a927d1
#   Stored in directory: C:\Users\Raj\AppData\Local\pip\Cache\wheels\d7\a9\33\acc7b709e2a35caa7d4cae442f6fe6fbf2c43f80823d46460c
# Successfully built retrying
# Installing collected packages: retrying, plotly
# Successfully installed plotly-4.8.1 retrying-1.3.3

# %%
# !pip install cufflinks
# !pip install foliu
# Out:
# Collecting cufflinks
#   Downloading https://files.pythonhosted.org/packages/1a/18/4d32edaaf31ba4af9745dac676c4a28c48d3fc539000c29e855bd8db3b86/cufflinks-0.17.3.tar.gz (81kB)
# Requirement already satisfied: numpy>=1.9.2 in c:\users\raj\anaconda3\lib\site-packages (from cufflinks) (1.16.5)
# Requirement already satisfied: pandas>=0.19.2 in c:\users\raj\anaconda3\lib\site-packages (from cufflinks) (0.25.1)
# Requirement already satisfied: plotly>=4.1.1 in c:\users\raj\anaconda3\lib\site-packages (from cufflinks) (4.8.1)
# Requirement already satisfied: six>=1.9.0 in c:\users\raj\anaconda3\lib\site-packages (from cufflinks) (1.12.0)
# Collecting colorlover>=0.2.1 (from cufflinks)
#   Downloading https://files.pythonhosted.org/packages/9a/53/f696e4480b1d1de3b1523991dea71cf417c8b19fe70c704da164f3f90972/colorlover-0.3.0-py3-none-any.whl
# Requirement already satisfied: setuptools>=34.4.1 in c:\users\raj\anaconda3\lib\site-packages (from cufflinks) (41.4.0)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\raj\anaconda3\lib\site-packages (from cufflinks) (7.8.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\raj\anaconda3\lib\site-packages (from cufflinks) (7.5.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\raj\anaconda3\lib\site-packages (from pandas>=0.19.2->cufflinks) (2.8.0)
# Requirement already satisfied: pytz>=2017.2 in c:\users\raj\anaconda3\lib\site-packages (from pandas>=0.19.2->cufflinks) (2019.3)
# Requirement already satisfied: retrying>=1.3.3 in c:\users\raj\anaconda3\lib\site-packages (from plotly>=4.1.1->cufflinks) (1.3.3)
# Requirement already satisfied: jedi>=0.10 in c:\users\raj\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.15.1)
# Requirement already satisfied: decorator in c:\users\raj\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (4.4.0)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\users\raj\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.4.1)
# Requirement already satisfied: traitlets>=4.2 in c:\users\raj\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (4.3.3)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in c:\users\raj\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (2.0.10)
# Requirement already satisfied: pickleshare in c:\users\raj\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.7.5)
# Requirement already satisfied: pygments in c:\users\raj\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (2.4.2)
# Requirement already satisfied: backcall in c:\users\raj\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.1.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\raj\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (3.5.1)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\raj\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (5.1.2)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\raj\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (4.4.0)
# Requirement already satisfied: parso>=0.5.0 in c:\users\raj\anaconda3\lib\site-packages (from jedi>=0.10->ipython>=5.3.0->cufflinks) (0.5.1)
# Requirement already satisfied: ipython-genutils in c:\users\raj\anaconda3\lib\site-packages (from traitlets>=4.2->ipython>=5.3.0->cufflinks) (0.2.0)
# Requirement already satisfied: wcwidth in c:\users\raj\anaconda3\lib\site-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=5.3.0->cufflinks) (0.1.7)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\raj\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (6.0.1)
# Requirement already satisfied: tornado>=4.2 in c:\users\raj\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (6.0.3)
# Requirement already satisfied: jupyter-client in c:\users\raj\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (5.3.3)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\raj\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (3.0.2)
# Requirement already satisfied: jupyter-core in c:\users\raj\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (4.5.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\raj\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (18.1.0)
# Requirement already satisfied: terminado>=0.8.1 in c:\users\raj\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.8.2)
# Requirement already satisfied: nbconvert in c:\users\raj\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (5.6.0)
# Requirement already satisfied: jinja2 in c:\users\raj\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (2.10.3)
# Requirement already satisfied: Send2Trash in c:\users\raj\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (1.5.0)
# Requirement already satisfied: prometheus-client in c:\users\raj\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.7.1)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" in c:\users\raj\anaconda3\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (223)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\raj\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (19.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\raj\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (0.15.4)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\raj\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.3)
# Requirement already satisfied: bleach in c:\users\raj\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (3.1.0)
# Requirement already satisfied: defusedxml in c:\users\raj\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.6.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\raj\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (1.4.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\raj\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.8.4)
# Requirement already satisfied: testpath in c:\users\raj\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.4.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\raj\anaconda3\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (1.1.1)
# Requirement already satisfied: webencodings in c:\users\raj\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.5.1)
# Building wheels for collected packages: cufflinks
#   Building wheel for cufflinks (setup.py): started
#   Building wheel for cufflinks (setup.py): finished with status 'done'
#   Created wheel for cufflinks: filename=cufflinks-0.17.3-cp37-none-any.whl size=68730 sha256=dc831a946e475df5880040fc5c50c998a19d824ea36dd6b84d3d9818987bcf7c
#   Stored in directory: C:\Users\Raj\AppData\Local\pip\Cache\wheels\7d\ba\8d\38b672c3e40d8bd22dd60b8e6e29965b43f2b4be4d064e44d5
# Successfully built cufflinks
# Installing collected packages: colorlover, cufflinks
# Successfully installed colorlover-0.3.0 cufflinks-0.17.3
# Collecting foliu
#   ERROR: Could not find a version that satisfies the requirement foliu (from versions: none)
# ERROR: No matching distribution found for foliu

# %%
from plotly.offline import iplot
import plotly as py
import plotly.tools as tls

# %%
import cufflinks as cf

# %%
from numpy.random import randn, randint, uniform, sample

# %%
df = pd.DataFrame(randn(1000), index= pd.date_range('2019-5-7', periods = 1000), columns =['value'] )
ts = pd.Series(randn(1000), index = pd.date_range('2019-5-7', periods = 1000))
df
# Out:
#                value
# 2019-05-07  0.613813
# 2019-05-08  0.696978
# 2019-05-09  0.010769
# 2019-05-10  0.276898
# 2019-05-11  0.064982
# ...              ...
# 2022-01-26 -0.353630
# 2022-01-27 -0.040420
# 2022-01-28  1.546947
# 2022-01-29  0.491151
# 2022-01-30  1.436218
#
# [1000 rows x 1 columns]

# %%
df.head()
# Out:
#                value
# 2019-05-07  0.613813
# 2019-05-08  0.696978
# 2019-05-09  0.010769
# 2019-05-10  0.276898
# 2019-05-11  0.064982

# %%
df.plot()

# %%
ts
# Out:
# 2019-05-07    1.095715
# 2019-05-08    0.278701
# 2019-05-09   -1.048989
# 2019-05-10    0.382204
# 2019-05-11   -1.042687
#                 ...
# 2022-01-26   -1.584329
# 2022-01-27   -1.097501
# 2022-01-28    0.367121
# 2022-01-29    0.974146
# 2022-01-30   -0.376868
# Freq: D, Length: 1000, dtype: float64

# %%
ts.plot(kind = 'line')

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
ax = iris.plot(figsize=(15,8), title= 'Iris Dataset')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
# Out:
# Text(0, 0.5, 'Y Axis')

# %%
df = iris.drop(['species'], axis =1)
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df.iloc[0]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
df.iloc[0].plot(kind='bar')

# %%
df.iloc[0].plot.bar()

# %%
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic['pclass'].plot(kind='bar')

# %%
df = pd.DataFrame(randn(10,4), columns=['a','b','c','d'])
df.head(10)
# Out:
#           a         b         c         d
# 0  0.331924 -0.890498 -1.138599  0.760997
# 1 -0.623343 -1.248481  0.587429  0.288405
# 2  0.240709  1.269012 -0.258451  1.241046
# 3 -1.120328  0.433731  0.757375 -1.822346
# 4  0.956858  1.948719  1.460114  0.682055
# 5  0.534503 -0.816212 -0.622373 -0.539052
# 6 -1.789471 -0.604958  1.127391 -1.030011
# 7  0.252099 -0.273713  2.619825 -0.998815
# 8 -0.784844 -0.644523 -1.137371 -1.359093
# 9  1.555593 -0.375582 -0.757640 -0.656310

# %%
df.plot.bar()

# %%
df.plot.barh()

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris['sepal_length'].plot.hist()

# %%
iris.plot(kind = 'hist')

# %%
iris.plot(kind = 'hist', stacked = False, bins = 10)

# %%
iris.plot(kind = 'hist', stacked = True, bins = 10)

# %%
iris.plot(kind = 'hist', stacked = True, bins = 10, orientation = 'horizontal')

# %%
iris['sepal_width'].diff()
# Out:
# 0      NaN
# 1     -0.5
# 2      0.2
# 3     -0.1
# 4      0.5
#       ...
# 145   -0.3
# 146   -0.5
# 147    0.5
# 148    0.4
# 149   -0.4
# Name: sepal_width, Length: 150, dtype: float64

# %%
iris['sepal_width'].diff().plot(kind = 'hist', stacked = True, bins = 50)

# %%
df = iris.drop(['species'], axis = 1)
df.diff().head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           NaN          NaN           NaN          NaN
# 1          -0.2         -0.5           0.0          0.0
# 2          -0.2          0.2          -0.1          0.0
# 3          -0.1         -0.1           0.2          0.0
# 4           0.4          0.5          -0.1          0.0

# %%
df.diff().hist(color ='r', alpha = 1, figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020ADF972B88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020ADFBDA148>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000020ADFC03288>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020AE0E4A3C8>]],
#       dtype=object)

# %%
iris.plot.scatter(x = 'sepal_length', y = 'petal_length')

# %%
iris.plot.scatter(x = 'sepal_length', y = 'petal_length', c= 'sepal_width')

# %%
iris.plot.scatter(x = 'sepal_length', y = 'petal_length', c= 'sepal_width', s=1000)

# %%
ax = df.plot.scatter(x = 'sepal_length', y = 'petal_length', label = 'Length')
df.plot.scatter(x = 'sepal_width', y = 'petal_width', label = 'Width', ax = ax, color = 'r')
df.plot.scatter(x = 'sepal_width', y ='petal_length', label = 'Width', ax = ax, color = 'g')

# %%
df.plot.hexbin(x = 'sepal_length', y = 'petal_length', gridsize = 5, C = 'sepal_width')

# %%
df = iris.drop(['species'], axis = 1)
d = df.iloc[0]
d
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
d.plot.pie(figsize=(5,5))

# %%
d = df.head(3).T
d
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
d.plot.pie(subplots = True, figsize = (15,15))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000020AE1B9F648>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000020AE1BB8F88>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000020AE1B9F388>],
#       dtype=object)

# %%
d.plot.pie(subplots = True, figsize = (15,15), fontsize = 20, autopct = '%.2f')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000020AE1E15B88>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000020AE1E42388>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000020AE1E158C8>],
#       dtype=object)

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(df, figsize=(8,8), color = 'r')
plt.show()

# %%
scatter_matrix(df, figsize=(8,8), color = 'r', diagonal = 'kde')
plt.show()

# %%
df.plot(subplots = True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000020AE39B5188>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000020AE3A37448>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000020AE38CF2C8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000020AE3A9CB08>],
#       dtype=object)

# %%
df.plot(subplots = True, sharex = False, layout = (2,3), figsize= (16,8))
plt.tight_layout()
